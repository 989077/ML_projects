# %%
# import the libs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('KNNAlgorithmDataset.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['Unnamed: 32'], inplace=True)

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['diagnosis'], inplace=True)

# %%
df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
print(df.duplicated().sum())
print(df.isnull().sum())
# Out:
# 0
# id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.head(10)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
# 5    843786        12.45         15.70           82.57      477.1
# 6    844359        18.25         19.98          119.60     1040.0
# 7  84458202        13.71         20.83           90.20      577.9
# 8    844981        13.00         21.82           87.50      519.8
# 9  84501001        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# ...

# %%
# Standardizing the data

from sklearn.preprocessing import  StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)
pd.DataFrame(data_scaled).describe()
# Out:
#                  0             1             2             3             4   \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean   1.248757e-17 -1.373633e-16  6.868164e-17 -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00
# min   -2.430790e-01 -2.029648e+00 -2.229249e+00 -1.984504e+00 -1.454443e+00
# 25%   -2.361897e-01 -6.893853e-01 -7.259631e-01 -6.919555e-01 -6.671955e-01
# 50%   -2.358950e-01 -2.150816e-01 -1.046362e-01 -2.359800e-01 -2.951869e-01
# 75%   -1.725930e-01  4.693926e-01  5.841756e-01  4.996769e-01  3.635073e-01
# max    7.052629e+00  3.971288e+00  4.651889e+00  3.976130e+00  5.250529e+00
#
#                  5             6             7             8             9   \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean  -8.366672e-16  1.873136e-16  4.995028e-17 -4.995028e-17  1.748260e-16
# ...

# %%
from sklearn.preprocessing import StandardScaler
# Example usage
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)
pd.DataFrame(data_scaled ).describe()
# Out:
#                  0             1             2             3             4   \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean   1.248757e-17 -1.373633e-16  6.868164e-17 -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00  1.000880e+00
# min   -2.430790e-01 -2.029648e+00 -2.229249e+00 -1.984504e+00 -1.454443e+00
# 25%   -2.361897e-01 -6.893853e-01 -7.259631e-01 -6.919555e-01 -6.671955e-01
# 50%   -2.358950e-01 -2.150816e-01 -1.046362e-01 -2.359800e-01 -2.951869e-01
# 75%   -1.725930e-01  4.693926e-01  5.841756e-01  4.996769e-01  3.635073e-01
# max    7.052629e+00  3.971288e+00  4.651889e+00  3.976130e+00  5.250529e+00
#
#                  5             6             7             8             9   \
# count  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02  5.690000e+02
# mean  -8.366672e-16  1.873136e-16  4.995028e-17 -4.995028e-17  1.748260e-16
# ...

# %%
df.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
kmeans = KMeans(n_clusters = 2, init='k-means++')
kmeans.fit(data_scaled)
kmeans.inertia_
# Out:
# 12163.187290220176

# %%
wcss =[]
for cluster in range(1,21):
    kmeans = KMeans(n_clusters = cluster, init='k-means++')
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(6,3))
plt.plot(range(1,21), wcss, marker='.')
plt.title('the elow curve')
plt.xlabel('number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# build the model with the 6 clusters

kmeans = KMeans(n_clusters=6, init='k-means++')
kmeans.fit(data_scaled)
pred = kmeans.predict(data_scaled)

df = pd.DataFrame(data_scaled)
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.236405  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515
# 1 -0.236403  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072
# 2  0.431741  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926
# 3  0.432121 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909
# 4  0.432201  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340
#
#          7         8         9   ...        21        22        23        24  \
# 0  2.652874  2.532475  2.217515  ...  1.886690 -1.359293  2.303601  2.001237
# 1 -0.023846  0.548144  0.001392  ...  1.805927 -0.369203  1.535126  1.890489
# 2  1.363478  2.037231  0.939685  ...  1.511870 -0.023974  1.347475  1.456285
# 3  1.915897  1.451707  2.867383  ... -0.281464  0.133984 -0.249939 -0.550021
# 4  1.371011  1.428493 -0.009560  ...  1.298575 -1.466770  1.338539  1.220724
#
#          25        26        27        28        29        30
# ...

# %%
df['cluster'] = pred
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.236405  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515
# 1 -0.236403  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072
# 2  0.431741  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926
# 3  0.432121 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909
# 4  0.432201  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340
#
#           7         8         9  ...        22        23        24        25  \
# 0  2.652874  2.532475  2.217515  ... -1.359293  2.303601  2.001237  1.307686
# 1 -0.023846  0.548144  0.001392  ... -0.369203  1.535126  1.890489 -0.375612
# 2  1.363478  2.037231  0.939685  ... -0.023974  1.347475  1.456285  0.527407
# 3  1.915897  1.451707  2.867383  ...  0.133984 -0.249939 -0.550021  3.394275
# 4  1.371011  1.428493 -0.009560  ... -1.466770  1.338539  1.220724  0.220556
#
#          26        27        28        29        30  cluster
# ...

# %%
df.tail(10)
# Out:
#             0         1         2         3         4         5         6  \
# 559 -0.235741 -0.743348  1.079841 -0.718729 -0.714976 -0.266890 -0.042470
# 560 -0.235741 -0.021952  1.829157 -0.024262 -0.154973  0.208495  0.156521
# 561 -0.235741 -0.831392  2.345765 -0.877311 -0.764748 -1.556408 -1.303122
# 562 -0.235738  0.310345  2.636649  0.470844  0.176365  0.600616  1.977758
# 563 -0.235734  1.929226  1.349781  2.101976  1.968434  0.963560  2.260135
# 564 -0.235732  2.110995  0.721473  2.060786  2.343856  1.041842  0.219060
# 565 -0.235730  1.704854  2.085134  1.615931  1.723842  0.102458 -0.017833
# 566 -0.235727  0.702284  2.045574  0.672676  0.577953 -0.840484 -0.038680
# 567 -0.235725  1.838341  2.336457  1.982524  1.735218  1.525767  3.272144
# 568 -0.242406 -1.808401  1.221792 -1.814389 -1.347789 -3.112085 -1.150752
#
#             7         8         9  ...        22        23        24  \
# 559  0.281240 -0.202977 -1.546608  ...  1.869899 -0.744086 -0.714386
# ...

# %%
df['cluster'].value_counts()
# Out:
# cluster
# 1    211
# 4    145
# 0     85
# 5     71
# 3     36
# 2     21
# Name: count, dtype: int64

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.236405  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515
# 1 -0.236403  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072
# 2  0.431741  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926
# 3  0.432121 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909
# 4  0.432201  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340
#
#           7         8         9  ...        22        23        24        25  \
# 0  2.652874  2.532475  2.217515  ... -1.359293  2.303601  2.001237  1.307686
# 1 -0.023846  0.548144  0.001392  ... -0.369203  1.535126  1.890489 -0.375612
# 2  1.363478  2.037231  0.939685  ... -0.023974  1.347475  1.456285  0.527407
# 3  1.915897  1.451707  2.867383  ...  0.133984 -0.249939 -0.550021  3.394275
# 4  1.371011  1.428493 -0.009560  ... -1.466770  1.338539  1.220724  0.220556
#
#          26        27        28        29        30  cluster
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Assuming you have already trained the models and have column names
# Example column names (replace with actual ones)
column_names = ['id', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'feature_6', 'feature_7', ...]

# Example data (this would come from your dataset)
X_train = np.random.rand(100, 31)  # Example dataset with 31 features

# Initialize and fit the scaler and kmeans
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_train)

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_scaled)

# Define the function
def get_cluster_prediction(scaler, kmeans, column_names):
    # Take user input for each feature, and make sure they match the expected column names
    user_data_dict = {col: 0 for col in column_names}  # Initialize all features with 0
    user_data_dict['id'] = int(input('Enter id: '))
    user_data_dict['radius_mean'] = float(input('Enter radius_mean: '))
    user_data_dict['texture_mean'] = float(input('Enter texture_mean: '))
    user_data_dict['perimeter_mean'] = float(input('Enter perimeter_mean: '))
    user_data_dict['area_mean'] = int(input('Enter area_mean: '))

    # Convert the user input into a DataFrame to match column names
    user_data = pd.DataFrame([user_data_dict])

    # Standardize the user input using the already fitted scaler
    user_data_scaled = scaler.transform(user_data)

    # Predict the cluster using the clustering model
    cluster = kmeans.predict(user_data_scaled)

    # Output the predicted cluster
    print(f"The customer belongs to cluster: {cluster[0]}")

# Call the function with the required arguments
get_cluster_prediction(scaler, kmeans, column_names)
# Out:
# Enter id:  24
# Enter radius_mean:  234
# Enter texture_mean:  4
# Enter perimeter_mean:  14

# %%
 get_cluster_prediction()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[545], line 1
# ----> 1 get_cluster_prediction()
#
# TypeError: get_cluster_prediction() missing 3 required positional arguments: 'scaler', 'kmeans', and 'column_names'
